# %%
import pyan

# %%
pyan --help
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-e1fc4e39973c> in <module>
# ----> 1 pyan --help
#
# TypeError: bad operand type for unary -: '_Helper'
